# %%
# This Program uses RNN(Recurrent Neural Network) called LSTM (Long short term memory) to predict the closing 
# stock price of company Tesla.

# %%
# Importing Libraries 
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns
sns.set_style('whitegrid')
import keras
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Importing Data
data_dir = 'Tesla.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")
df
# Out:
#                   Open        High  ...    Volume   Adj Close
# Date                                ...
# 2010-06-29   19.000000   25.000000  ...  18766300   23.889999
# 2010-06-30   25.790001   30.420000  ...  17187100   23.830000
# 2010-07-01   25.000000   25.920000  ...   8218800   21.959999
# 2010-07-02   23.000000   23.100000  ...   5139800   19.200001
# 2010-07-06   20.000000   20.000000  ...   6866900   16.110001
# ...                ...         ...  ...       ...         ...
# 2017-03-13  244.820007  246.850006  ...   3010700  246.169998
# 2017-03-14  246.110001  258.119995  ...   7575500  258.000000
# 2017-03-15  257.000000  261.000000  ...   4816600  255.729996
# 2017-03-16  262.399994  265.750000  ...   7100400  262.049988
# 2017-03-17  264.000000  265.329987  ...   6475900  261.500000
#
# [1692 rows x 6 columns]

# %%
df.head()
# Out:
#                  Open   High        Low      Close    Volume  Adj Close
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1692 entries, 2010-06-29 to 2017-03-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5 KB

# %%
df.describe()
# Out:
#               Open         High  ...        Volume    Adj Close
# count  1692.000000  1692.000000  ...  1.692000e+03  1692.000000
# mean    132.441572   134.769698  ...  4.270741e+06   132.428658
# std      94.309923    95.694914  ...  4.295971e+06    94.313187
# min      16.139999    16.629999  ...  1.185000e+05    15.800000
# 25%      30.000000    30.650000  ...  1.194350e+06    29.884999
# 50%     156.334999   162.370002  ...  3.180700e+06   158.160004
# 75%     220.557495   224.099999  ...  5.662100e+06   220.022503
# max     287.670013   291.420013  ...  3.716390e+07   286.040009
#
# [8 rows x 6 columns]

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
# We'll use pct_change to find the percent change for each day
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=100)
plt.ylabel('Daily Return')
plt.title(f'Tesla Daily Return')
plt.tight_layout()
plt.show()

# %%
# Performing Data Preprocessing & Predicting the Closing of Tesla stock
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (1692, 1)

# %%
# Normalizing the Dataset

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
# Splitting the Data into Test & Train
# 70% Train & 30% Test

train_size = int(len(data)*.70)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 1184 Test Size : 508

# %%
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape , y_train.shape
# Out:
# ((1124, 60, 1), (1124,))

# %%
# LSTM (Long short term memory)
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Training

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 36/36 [==============================] - 5s 47ms/step - loss: 0.0204 - mean_absolute_error: 0.0840
# Epoch 2/100
# 36/36 [==============================] - 2s 50ms/step - loss: 0.0012 - mean_absolute_error: 0.0223
# Epoch 3/100
# 36/36 [==============================] - 2s 48ms/step - loss: 0.0011 - mean_absolute_error: 0.0205
# Epoch 4/100
# 36/36 [==============================] - 2s 47ms/step - loss: 0.0010 - mean_absolute_error: 0.0198
# Epoch 5/100
# 36/36 [==============================] - 2s 47ms/step - loss: 0.0010 - mean_absolute_error: 0.0199
# Epoch 6/100
# 36/36 [==============================] - 2s 49ms/step - loss: 9.9406e-04 - mean_absolute_error: 0.0197
# Epoch 7/100
# 36/36 [==============================] - 2s 46ms/step - loss: 9.5472e-04 - mean_absolute_error: 0.0195
# Epoch 8/100
# 36/36 [==============================] - 2s 44ms/step - loss: 0.0010 - mean_absolute_error: 0.0202
# Epoch 9/100
# 36/36 [==============================] - 2s 49ms/step - loss: 8.3225e-04 - mean_absolute_error: 0.0178
# Epoch 10/100
# 36/36 [==============================] - 2s 49ms/step - loss: 8.5095e-04 - mean_absolute_error: 0.0184
# Epoch 11/100
# 36/36 [==============================] - 2s 47ms/step - loss: 8.6719e-04 - mean_absolute_error: 0.0187
# Epoch 12/100
# 36/36 [==============================] - 2s 65ms/step - loss: 0.0011 - mean_absolute_error: 0.0214
# Epoch 13/100
# 36/36 [==============================] - 3s 72ms/step - loss: 7.1485e-04 - mean_absolute_error: 0.0167
# Epoch 14/100
# 36/36 [==============================] - 2s 45ms/step - loss: 6.8917e-04 - mean_absolute_error: 0.0165
# Epoch 15/100
# 36/36 [==============================] - 2s 45ms/step - loss: 6.7601e-04 - mean_absolute_error: 0.0162
# Epoch 16/100
# 36/36 [==============================] - 2s 47ms/step - loss: 7.8934e-04 - mean_absolute_error: 0.0178
# Epoch 17/100
# 36/36 [==============================] - 2s 48ms/step - loss: 6.7751e-04 - mean_absolute_error: 0.0165
# Epoch 18/100
# 36/36 [==============================] - 2s 49ms/step - loss: 6.3123e-04 - mean_absolute_error: 0.0158
# Epoch 19/100
# 36/36 [==============================] - 2s 48ms/step - loss: 6.8148e-04 - mean_absolute_error: 0.0165
# Epoch 20/100
# 36/36 [==============================] - 2s 47ms/step - loss: 6.6196e-04 - mean_absolute_error: 0.0162
# Epoch 21/100
# 36/36 [==============================] - 2s 47ms/step - loss: 7.1617e-04 - mean_absolute_error: 0.0165
# Epoch 22/100
# 36/36 [==============================] - 2s 48ms/step - loss: 6.0890e-04 - mean_absolute_error: 0.0153
# Epoch 23/100
# 36/36 [==============================] - 2s 48ms/step - loss: 5.9490e-04 - mean_absolute_error: 0.0154
# Epoch 24/100
# 36/36 [==============================] - 2s 48ms/step - loss: 6.6174e-04 - mean_absolute_error: 0.0166
# Epoch 25/100
# 36/36 [==============================] - 2s 44ms/step - loss: 6.5386e-04 - mean_absolute_error: 0.0155
# Epoch 26/100
# 36/36 [==============================] - 2s 45ms/step - loss: 5.9786e-04 - mean_absolute_error: 0.0156
# Epoch 27/100
# 36/36 [==============================] - 2s 49ms/step - loss: 5.7989e-04 - mean_absolute_error: 0.0145
# Epoch 28/100
# 36/36 [==============================] - 2s 47ms/step - loss: 5.9878e-04 - mean_absolute_error: 0.0157
# Epoch 29/100
# 36/36 [==============================] - 2s 49ms/step - loss: 5.3003e-04 - mean_absolute_error: 0.0144
# Epoch 30/100
# 36/36 [==============================] - 2s 50ms/step - loss: 5.4320e-04 - mean_absolute_error: 0.0145
# Epoch 31/100
# 36/36 [==============================] - 2s 47ms/step - loss: 5.2345e-04 - mean_absolute_error: 0.0142
# Epoch 32/100
# 36/36 [==============================] - 2s 51ms/step - loss: 5.3473e-04 - mean_absolute_error: 0.0150
# Epoch 33/100
# 36/36 [==============================] - 2s 51ms/step - loss: 4.6338e-04 - mean_absolute_error: 0.0134
# Epoch 34/100
# 36/36 [==============================] - 2s 45ms/step - loss: 5.1445e-04 - mean_absolute_error: 0.0142
# Epoch 35/100
# 36/36 [==============================] - 2s 50ms/step - loss: 4.6943e-04 - mean_absolute_error: 0.0136
# Epoch 36/100
# 36/36 [==============================] - 2s 66ms/step - loss: 4.1642e-04 - mean_absolute_error: 0.0120
# Epoch 37/100
# 36/36 [==============================] - 2s 49ms/step - loss: 4.1336e-04 - mean_absolute_error: 0.0123
# Epoch 38/100
# 36/36 [==============================] - 2s 46ms/step - loss: 4.4976e-04 - mean_absolute_error: 0.0133
# Epoch 39/100
# 36/36 [==============================] - 2s 49ms/step - loss: 4.6986e-04 - mean_absolute_error: 0.0135
# Epoch 40/100
# 36/36 [==============================] - 2s 50ms/step - loss: 5.1769e-04 - mean_absolute_error: 0.0147
# Epoch 41/100
# 36/36 [==============================] - 2s 48ms/step - loss: 4.0504e-04 - mean_absolute_error: 0.0126
# Epoch 42/100
# 36/36 [==============================] - 2s 49ms/step - loss: 4.7375e-04 - mean_absolute_error: 0.0137
# Epoch 43/100
# 36/36 [==============================] - 2s 70ms/step - loss: 3.7766e-04 - mean_absolute_error: 0.0118
# Epoch 44/100
# 36/36 [==============================] - 2s 45ms/step - loss: 3.7181e-04 - mean_absolute_error: 0.0117
# Epoch 45/100
# 36/36 [==============================] - 2s 46ms/step - loss: 3.7209e-04 - mean_absolute_error: 0.0115
# Epoch 46/100
# 36/36 [==============================] - 2s 49ms/step - loss: 4.0033e-04 - mean_absolute_error: 0.0122
# Epoch 47/100
# 36/36 [==============================] - 2s 46ms/step - loss: 4.0051e-04 - mean_absolute_error: 0.0127
# Epoch 48/100
# 36/36 [==============================] - 2s 53ms/step - loss: 2.5704e-04 - mean_absolute_error: 0.0095
# Epoch 76/100
# 36/36 [==============================] - 2s 51ms/step - loss: 2.5084e-04 - mean_absolute_error: 0.0096
# Epoch 77/100
# 36/36 [==============================] - 3s 76ms/step - loss: 2.9754e-04 - mean_absolute_error: 0.0105
# Epoch 78/100
# 36/36 [==============================] - 3s 77ms/step - loss: 2.6268e-04 - mean_absolute_error: 0.0099
# Epoch 79/100
# 36/36 [==============================] - 4s 109ms/step - loss: 2.5519e-04 - mean_absolute_error: 0.0096
# Epoch 80/100
# 36/36 [==============================] - 4s 122ms/step - loss: 2.4453e-04 - mean_absolute_error: 0.0091
# Epoch 81/100
# 36/36 [==============================] - 5s 126ms/step - loss: 2.6870e-04 - mean_absolute_error: 0.0100
# Epoch 82/100
# 36/36 [==============================] - 3s 83ms/step - loss: 4.1463e-04 - mean_absolute_error: 0.0134
# Epoch 83/100
# 36/36 [==============================] - 3s 82ms/step - loss: 2.7672e-04 - mean_absolute_error: 0.0103
# Epoch 84/100
# 36/36 [==============================] - 5s 130ms/step - loss: 3.5917e-04 - mean_absolute_error: 0.0120
# Epoch 85/100
# 36/36 [==============================] - 3s 75ms/step - loss: 2.8710e-04 - mean_absolute_error: 0.0105
# Epoch 86/100
# 36/36 [==============================] - 2s 50ms/step - loss: 2.6481e-04 - mean_absolute_error: 0.0097
# Epoch 87/100
# 36/36 [==============================] - 2s 63ms/step - loss: 3.0076e-04 - mean_absolute_error: 0.0110
# Epoch 88/100
# 36/36 [==============================] - 2s 54ms/step - loss: 3.1660e-04 - mean_absolute_error: 0.0114
# Epoch 89/100
# 36/36 [==============================] - 2s 63ms/step - loss: 4.5187e-04 - mean_absolute_error: 0.0150
# Epoch 90/100
# 36/36 [==============================] - 3s 71ms/step - loss: 4.2271e-04 - mean_absolute_error: 0.0134

# %%
# Evaluating the Model
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Testing the Data set

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((508, 60, 1), (508,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 16/16 [==============================] - 2s 13ms/step
# (508, 1)

# %%
# RMSE (Root mean square error)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.17

# %%
# Visualizing the Predicted Data of Tesla stock

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
